# %%
import pandas as pd

# users = pd.read_csv('data/users_export.csv')
ratings = pd.read_csv('data/ratings_export.csv')
movies = pd.read_csv('data/movie_data.csv', on_bad_lines='skip')
my_ratings = pd.read_csv('data/processed/ratings_tmdb_cleaned.csv')

# Merge datasets on movie_id to create a comprehensive dataset
user_ratings = pd.merge(ratings, movies, left_on='movie_id', right_on='movie_id')

# %%
user_ratings.head()
# Out:
#                       _id_x    movie_id  rating_val         user_id  \
# 0  5fc57c5d6758f6963451a07f  feast-2014           7      deathproof
# 1  5fc57ca06758f69634538bad  feast-2014          10  ingridgoeswest
# 2  5fc57cbd6758f696345475a3  feast-2014           8           dirkh
# 3  5fc57ce06758f6963455400b  feast-2014          10   childrenofmen
# 4  5fc57cf36758f69634558b0e  feast-2014           8      suspirliam
#
#                       _id_y                                   genres  \
# 0  5fc880726758f69634df0bca  ["Animation","Comedy","Drama","Family"]
# 1  5fc880726758f69634df0bca  ["Animation","Comedy","Drama","Family"]
# 2  5fc880726758f69634df0bca  ["Animation","Comedy","Drama","Family"]
# 3  5fc880726758f69634df0bca  ["Animation","Comedy","Drama","Family"]
# 4  5fc880726758f69634df0bca  ["Animation","Comedy","Drama","Family"]
#
#                                            image_url    imdb_id  \
# 0  film-poster/2/2/0/1/9/2/220192-feast-0-230-0-3...  tt3689498
# 1  film-poster/2/2/0/1/9/2/220192-feast-0-230-0-3...  tt3689498
# 2  film-poster/2/2/0/1/9/2/220192-feast-0-230-0-3...  tt3689498
# 3  film-poster/2/2/0/1/9/2/220192-feast-0-230-0-3...  tt3689498
# 4  film-poster/2/2/0/1/9/2/220192-feast-0-230-0-3...  tt3689498
#
#                                          imdb_link movie_title  ...  \
# 0  http://www.imdb.com/title/tt3689498/maindetails       Feast  ...
# 1  http://www.imdb.com/title/tt3689498/maindetails       Feast  ...
# 2  http://www.imdb.com/title/tt3689498/maindetails       Feast  ...
# 3  http://www.imdb.com/title/tt3689498/maindetails       Feast  ...
# 4  http://www.imdb.com/title/tt3689498/maindetails       Feast  ...
#
#   popularity          production_countries  release_date runtime  \
# 0       9.26  ["United States of America"]    2014-10-25     6.0
# 1       9.26  ["United States of America"]    2014-10-25     6.0
# 2       9.26  ["United States of America"]    2014-10-25     6.0
# 3       9.26  ["United States of America"]    2014-10-25     6.0
# 4       9.26  ["United States of America"]    2014-10-25     6.0
#
#   spoken_languages   tmdb_id                                 tmdb_link  \
# 0      ["English"]  293299.0  https://www.themoviedb.org/movie/293299/
# 1      ["English"]  293299.0  https://www.themoviedb.org/movie/293299/
# 2      ["English"]  293299.0  https://www.themoviedb.org/movie/293299/
# 3      ["English"]  293299.0  https://www.themoviedb.org/movie/293299/
# 4      ["English"]  293299.0  https://www.themoviedb.org/movie/293299/
#
#    vote_average vote_count  year_released
# 0           7.9      720.0         2014.0
# 1           7.9      720.0         2014.0
# 2           7.9      720.0         2014.0
# 3           7.9      720.0         2014.0
# 4           7.9      720.0         2014.0
#
# [5 rows x 22 columns]

# %%
len(user_ratings)
# Out:
# 11079666

# %%
len(my_ratings)
# Out:
# 186

# %%
# Filter users who have rated Interstellar 10/10
interstellar_10 = user_ratings[(user_ratings['movie_title'] == 'Interstellar') & (user_ratings['rating_val'] == 10)]

# Filter users who have rated La La Land 10/10
la_la_land_10 = user_ratings[(user_ratings['movie_title'] == 'La La Land') & (user_ratings['rating_val'] == 10)]

about_time_10 = user_ratings[(user_ratings['movie_title'] == 'About Time') & (user_ratings['rating_val'] == 10)]

# Get user_ids who rated Interstellar 10/10
interstellar_users_10 = interstellar_10['user_id']

# Get user_ids who rated La La Land 10/10
la_la_land_users_10 = la_la_land_10['user_id']

# Find common users who rated both movies 10/10
common_users_10 = interstellar_users_10[interstellar_users_10.isin(la_la_land_users_10)]
common_users_10 = common_users_10[common_users_10.isin(about_time_10['user_id'])]

print(common_users_10)
# Out:
# 2633188          niceguys
# 2633211          mskiesha
# 2633229             milez
# 2633309          ianjonas
# 2633416    kennedylizrose
#                 ...
# 2637153           jnawsty
# 2637703           cami123
# 2637734           erfrost
# 2637807            joelca
# 2637888             etiam
# Name: user_id, Length: 67, dtype: object
